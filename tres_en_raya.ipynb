# %%
#tablero
huecos_tablero = {'a1':'-', 'b1':'-', 'c1':'-', 'a2':'-', 'b2':'-', 'c2':'-', 'a3':'-', 'b3':'-', 'c3':'-'} 

tablero = f'''
          +-----+-----+-----+
          |  a  |  b  |  c  |
      _______________________
      | 1 |  {huecos_tablero['a1']}  |  {huecos_tablero['b1']}  |  {huecos_tablero['c1']}  |
      _______________________
      | 2 |  {huecos_tablero['a2']}  |  {huecos_tablero['b2']}  |  {huecos_tablero['c2']}  |
      _______________________
      | 3 |  {huecos_tablero['a3']}  |  {huecos_tablero['b3']}  |  {huecos_tablero['c3']}  |
      +---+-----+-----+-----+
      '''
print(tablero)

for coordenada in huecos_tablero:
# Juega X   
 
    coordenada_X = input('JUGADOR X, Dime la coordenada para tu ficha')
    while huecos_tablero[coordenada_X] != '-': #comprobando que el hueco está disponible
        print ('Ese hueco no está disponible')
        break
    else:    
        print('El hueco está disponible')#si lo está, cambia '-' por X
        huecos_tablero[coordenada_X]= 'X'

# Juega O
    coordenada_O = input('JUGADOR O, Dime la coordenada para tu ficha')#igual con el jugador X
    while huecos_tablero[coordenada_O] != '-':
        print ('Ese hueco no está disponible')
        break
    else:
        print('El hueco está disponible')
        huecos_tablero[coordenada_O] = 'O'
        break

lista_valores_tablero = list(huecos_tablero.values())
print (lista_valores_tablero)



for espacio in range(len(lista_valores_tablero)):

    if lista_valores_tablero[espacio] == 'X':
        lista_valores_tablero[espacio] = 1

    elif lista_valores_tablero[espacio] == 'O':        
        lista_valores_tablero[espacio] = 4
        
    else:
        lista_valores_tablero[espacio] = 0

print (lista_valores_tablero)    


#a1,b1,c1,a2,b2,c2,a3,b3,c3
# 0, 1, 2, 3, 4, 5, 6, 7, 8

#sustituir - por 0
#sustituir X por 1
#sustituir O por 4






#si suma de las lineas = 0, nada
#si suma de las lineas = 3 , X win
#si suma de las lineas = 12 , O win
#si suma de las lineas diferente a los anteriores, nada



# Comprobando win

if sum(lista_valores_tablero[0:3])==3 or sum(lista_valores_tablero)==12:
    print(f'Ganador: jugador {huecos_tablero['a1']}')



    print(sum(lista_valores_tablero[0:3]))
    ganador = huecos_tablero['a1']
    print(f' Jugador {ganador} ¡¡¡Has ganado!!!') #cualquiera de las coordenadas. Vas a ser todas iguales
   
elif len (set(['a2','b2','c2']))==3 and ['a2','b2','c2'] != ['-','-','-']:
    print(len(set(['a2','b2','c2'])))
    ganador=huecos_tablero['a2']
    print(f' Jugador {ganador} ¡¡¡Has ganado!!!') 

elif len (set(['a3','b3','c3']))==3 and ['a3','b3','c3'] != ['-','-','-']:
    print(len(set(['a3','b3','c3'])))
    ganador=huecos_tablero['a3']
    print(f' Jugador {ganador} ¡¡¡Has ganado!!!')

elif len (set(['a1','a2','a3']))==3 and ['a1','a2','a3'] != ['-','-','-']:
    print(len(set(['a1','a2','a3'])))
    ganador=huecos_tablero['a1']
    print(f' Jugador {ganador} ¡¡¡Has ganado!!!') 

elif len (set(['c1','c2','c3']))==3 and ['c1','c2','c3'] != ['-','-','-']:
    print(len(set(['c1','c2','c3'])))
    ganador=huecos_tablero['c1']    
    print(f' Jugador {ganador} ¡¡¡Has ganado!!!')

elif len (set(['a1','b2','c3']))==3 and ['a1','b2','c3'] != ['-','-','-']:
    print(len(set(['a1','b2','c3'])))
    ganador=huecos_tablero['a1']
    print(f' Jugador {ganador} ¡¡¡Has ganado!!!') 

elif len (set(['a1','b2','c3']))==3 and ['a1','b2','c3'] != ['-','-','-']:
    print(len(set(['a3','b2','c1'])))
    ganador=huecos_tablero['a3']
    print(f' Jugador {ganador} ¡¡¡Has ganado!!!') 

else:

    print(huecos_tablero)
# Out:
#           +-----+-----+-----+
#           |  a  |  b  |  c  |
#       _______________________
#       | 1 |  -  |  -  |  -  |
#       _______________________
#       | 2 |  -  |  -  |  -  |
#       _______________________
#       | 3 |  -  |  -  |  -  |
#       +---+-----+-----+-----+
# El hueco está disponible
# El hueco está disponible
# ['X', '-', '-', '-', 'O', '-', '-', '-', '-']
# [1, 0, 0, 0, 4, 0, 0, 0, 0]
# 1
#  Jugador X ¡¡¡Has ganado!!!
