# %%
#tablero
huecos_tablero = {'a1':'-', 'b1':'-', 'c1':'-', 'a2':'-', 'b2':'-', 'c2':'-', 'a3':'-', 'b3':'-', 'c3':'-'} 

tablero = f'''
          +-----+-----+-----+
          |  a  |  b  |  c  |
      _______________________
      | 1 |  {huecos_tablero['a1']}  |  {huecos_tablero['b1']}  |  {huecos_tablero['c1']}  |
      _______________________
      | 2 |  {huecos_tablero['a2']}  |  {huecos_tablero['b2']}  |  {huecos_tablero['c2']}  |
      _______________________
      | 3 |  {huecos_tablero['a3']}  |  {huecos_tablero['b3']}  |  {huecos_tablero['c3']}  |
      +---+-----+-----+-----+
      '''
print(tablero)

while True:
    coordenada_X = input('JUGADOR X, Dime la coordenada para tu ficha')
    coordenada_O = input('JUGADOR O, Dime la coordenada para tu ficha')#igual con el jugador X



    for coordenada in huecos_tablero:

        if '-' not in huecos_tablero:
            print('empate')
            break
# Juega X   
         
        if huecos_tablero[coordenada_X] == '-': #comprobando que el hueco está disponible
            print('El hueco está disponible')#si lo está, cambia '-' por X
            huecos_tablero[coordenada_X]= 'X'         
            
        else:    
             print ('Ese hueco no está disponible')
             coordenada_X = input('JUGADOR X, Dime la coordenada para tu ficha')

# Juega O
        
        if huecos_tablero[coordenada_O] == '-':
            print('El hueco está disponible')
            huecos_tablero[coordenada_O] = 'O'
            
            
        else:
            print ('Ese hueco no está disponible')
            coordenada_O = input('JUGADOR O, Dime la coordenada para tu ficha')




        #a1-b1-c1
        if huecos_tablero['a1'] and huecos_tablero['b1'] and huecos_tablero['c1']=='X':
            print('Ha ganado el jugador X')
            break

        elif huecos_tablero['a1'] and huecos_tablero['b1'] and huecos_tablero['c1']=='O':
            print('Ha ganado el jugador O')
            break

        #a2-b2-c2
        elif huecos_tablero['a2'] and huecos_tablero['b2'] and huecos_tablero['c2']=='X':
            print('Ha ganado el jugador X')
            break

        elif huecos_tablero['a2'] and huecos_tablero['b2'] and huecos_tablero['c2']=='O':
            print('Ha ganado el jugador O')
            break

        #a3-b3-c3
        elif huecos_tablero['a3'] and huecos_tablero['b3'] and huecos_tablero['c3']=='X':
            print('Ha ganado el jugador X')
            break

        elif huecos_tablero['a3'] and huecos_tablero['b3'] and huecos_tablero['c3']=='O':
            print('Ha ganado el jugador O')
            break

        #a1-a2-a3
        elif huecos_tablero['a1'] and huecos_tablero['a2'] and huecos_tablero['a3']=='X':
            print('Ha ganado el jugador X')

        elif huecos_tablero['a1'] and huecos_tablero['a2'] and huecos_tablero['a3']=='O':    
            print('Ha ganado el jugador O')
            break

        #b1-b2-b3
        elif huecos_tablero['b1'] and huecos_tablero['b2'] and huecos_tablero['b3']=='X':
            print('Ha ganado el jugador X')
            break

        elif huecos_tablero['b1'] and huecos_tablero['b2'] and huecos_tablero['b3']=='O':
            print('Ha ganado el jugador O')
            break

        #c1-c2-c3
        elif huecos_tablero['c1'] and huecos_tablero['c2'] and huecos_tablero['c3']=='X':
            print('Ha ganado el jugador X')
            break

        elif huecos_tablero['c1'] and huecos_tablero['c2'] and huecos_tablero['c3']=='O':    
            print('Ha ganado el jugador O')
            break

        #a1-b2-c3
        elif huecos_tablero['a1'] and huecos_tablero['b2'] and huecos_tablero['c3']=='X':
            print('Ha ganado el jugador X')
            break

        elif huecos_tablero['a1'] and huecos_tablero['b2'] and huecos_tablero['c3']=='O':
            print('Ha ganado el jugador O')
            break

        #a3-b2-c1
        elif huecos_tablero['a3'] and huecos_tablero['b2'] and huecos_tablero['c1']=='X':
            print('Ha ganado el jugador X')
            break

        elif huecos_tablero['a3'] and huecos_tablero['b2'] and huecos_tablero['c1']=='O':
            print('Ha ganado el jugador O')
            break

        else:
            print ('error')
            break
# Out:
#           +-----+-----+-----+
#           |  a  |  b  |  c  |
#       _______________________
#       | 1 |  -  |  -  |  -  |
#       _______________________
#       | 2 |  -  |  -  |  -  |
#       _______________________
#       | 3 |  -  |  -  |  -  |
#       +---+-----+-----+-----+
#
# empate
# empate
# empate
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 19
#      17 while True:
#      18     coordenada_X = input('JUGADOR X, Dime la coordenada para tu ficha')
# ---> 19     coordenada_O = input('JUGADOR O, Dime la coordenada para tu ficha')#igual con el jugador X
#      23     for coordenada in huecos_tablero:
#      25         if huecos_tablero.values() != '-':
#
# File ~/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
if sum(lista_valores_tablero[0,1,2])==3 or sum(lista_valores_tablero[3,4,5])==3 or sum(lista_valores_tablero[6,7,8])==3 or sum(lista_valores_tablero[0,3,6])==3 or sum(lista_valores_tablero[1,4,7])==3 or sum(lista_valores_tablero[2,5,8])==3 or sum(lista_valores_tablero[0,4,8])==3 or sum(lista_valores_tablero[2,4,6])==3:
    print('Ha ganado el jugador X')


elif sum(lista_valores_tablero[0,1,2])==12 or sum(lista_valores_tablero[3,4,5])==12 or sum(lista_valores_tablero[6,7,8])==12 or sum(lista_valores_tablero[0,3,6])==12 or sum(lista_valores_tablero[1,4,7])==12 or sum(lista_valores_tablero[2,5,8])==12 or sum(lista_valores_tablero[0,4,8])==12 or sum(lista_valores_tablero[2,4,6])==12:
    print('Ha ganado el jugador O') 

else:
    print ('Error')
